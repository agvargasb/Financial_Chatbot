# %% [markdown]
# This notebook downloads the dataset from S3 to google drive. Please run this notebook in google colab and be careful with the paths.

# %%
# !pip install boto3

# %%
# !pip install cloudpathlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import boto3
from cloudpathlib import S3Client, S3Path
from pathlib import Path

# %%
DATASET = "s3://anyoneai-datasets/nasdaq_annual_reports/"
# BUCKET_NAME = "anyoneai-datasets"
ACCESS_KEY = "AKIA2JHUK4EGBAMYAYFY"
SECRET_KEY = "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"

# %%
client = S3Client(aws_access_key_id=ACCESS_KEY,
                  aws_secret_access_key=SECRET_KEY)

# %%
dataset_path = S3Path(DATASET, client=client)

# %%
dataset_path.bucket
# Out:
# 'anyoneai-datasets'

# %%
folder_paths = dataset_path.glob("*")
folders = []

for path in folder_paths:
  folders.append(path)

# %%
folders
# Out:
# [S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/1-800-flowerscom'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/10x-genomics-inc'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/111-inc'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/1347-property-insurance-holdings-inc'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/1895-bancorp-of-wisconsin-inc'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/1st-source-corporation'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/21vianet-group-inc'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/2u-inc'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/360-finance-inc'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/36kr-holdings-inc'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/3d-systems-corp'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/51job-inc'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/89bio-inc'),
# ...

# %%
filepaths = dataset_path.glob("*/*")
files = []

for path in filepaths:
  files.append(path)

# %%
files
# Out:
# [S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/1-800-flowerscom/NASDAQ_FLWS_2019.pdf'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/1-800-flowerscom/NASDAQ_FLWS_2020.pdf'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/1-800-flowerscom/NASDAQ_FLWS_2021.pdf'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/1-800-flowerscom/NASDAQ_FLWS_2022.pdf'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/10x-genomics-inc/NASDAQ_TXG_2019.pdf'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/10x-genomics-inc/NASDAQ_TXG_2020.pdf'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/10x-genomics-inc/NASDAQ_TXG_2021.pdf'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/111-inc/NASDAQ_YI_2018.pdf'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/111-inc/NASDAQ_YI_2019.pdf'),
#  S3Path('s3://anyoneai-datasets/nasdaq_annual_reports/111-inc/NASDAQ_YI_2020.pdf'),
# ...

# %%
len(files)
# Out:
# 9855

# %%
# !pwd
# Out:
# /content

# %%
local_filepaths = Path("dataset").glob("*/*")
local_files = []

for path in local_filepaths:
  local_files.append(path)

# %%
len(local_files)
# Out:
# 1837

# %%
1837/9855
# Out:
# 0.18640284119736175

# %%
(2 * 9855)/1000
# Out:
# 19.71

# %%
# !mkdir dataset

# %%
# %%time
dataset_path.download_to("dataset")
# Out:
# CPU times: user 14min 45s, sys: 3min 42s, total: 18min 27s
# Wall time: 4h 31min 52s
# PosixPath('dataset')

# %%
# !pwd
# Out:
# /content

# %%
# !cp -R dataset/. drive/MyDrive/Anyone_AI/Final_Project/Raw_Data/

# %%
local_filepaths = Path("drive/MyDrive/Anyone_AI/Final_Project/Raw_Data").glob("*/*")
local_files = []

for path in local_filepaths:
  local_files.append(path)

# %%
len(local_files)
# Out:
# 9855
